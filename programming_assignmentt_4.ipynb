# %% [markdown]
# # Programming_Assignment_4

# %%
#1.	Write a Python Program to Find the Factorial of a Number?
def factorial_of_number(number):
    factorial = 1
    for i in range(1,number+1):
        factorial = factorial*i
    return factorial

number  = int(input("Enter a number"))
factorial_of_number(number)

# %%
#2.	Write a Python Program to Display the multiplication Table?
def display_multiplication_table(number):
    for i in range(1,11):
        multiplied = number*i
        print(number," * ",i," = ",multiplied)
number = int(input("Enter the number for which you want multiplication table"))
display_multiplication_table(number)

# %%
#3.	Write a Python Program to Print the Fibonacci sequence?
a = 0
b = 1
number = int(input("Enter the range"))
if number==2:
    print("0,1")
else:
    print("0 1",end=" ")
    for i in range(2,number):
        value = a+b
        print(value,end=" ")
        a,b = b,value

# %%
#4.	Write a Python Program to Check Armstrong Number?
number   = int(input("Enter the number"))
sum = 0
temp = number
while number>0:
    remainder = number%10
    sum = sum + remainder**3
    number = number//10
if (temp==sum):
    print("{} is armstrong number".format(temp))
else:
    print("{} is not a armstrong number".format(temp))
# Out:
# Enter the number153
# 153 is armstrong number

# %%
#5.	Write a Python Program to Find Armstrong Number in an Interval?
lower = int(input("enter the lower limit "))
upper = int(input("enter the upper limit "))
for i in range(lower,upper+1):
    number = i
    sum=0
    temp = number
    while number>0:
        remainder = number%10
        sum = sum+remainder**3
        number = number//10
    if temp==sum:
        print("{} is armstrong number".format(temp))
    else:
        print("{} is not a armstrong number".format(temp))
# Out:
# enter the lower limit 0
# enter the upper limit 154
# 0 is armstrong number
# 1 is armstrong number
# 2 is not a armstrong number
# 3 is not a armstrong number
# 4 is not a armstrong number
# 5 is not a armstrong number
# 6 is not a armstrong number
# 7 is not a armstrong number
# 8 is not a armstrong number
# 9 is not a armstrong number
# 10 is not a armstrong number
# 11 is not a armstrong number
# 12 is not a armstrong number
# 13 is not a armstrong number
# 14 is not a armstrong number
# 15 is not a armstrong number
# 16 is not a armstrong number
# 17 is not a armstrong number
# 18 is not a armstrong number
# 19 is not a armstrong number
# 20 is not a armstrong number
# 21 is not a armstrong number
# 22 is not a armstrong number
# 23 is not a armstrong number
# 24 is not a armstrong number
# 25 is not a armstrong number
# 26 is not a armstrong number
# 27 is not a armstrong number
# 28 is not a armstrong number
# 29 is not a armstrong number
# 30 is not a armstrong number
# 31 is not a armstrong number
# 32 is not a armstrong number
# 33 is not a armstrong number
# 34 is not a armstrong number
# 35 is not a armstrong number
# 36 is not a armstrong number
# 37 is not a armstrong number
# 38 is not a armstrong number
# 39 is not a armstrong number
# 40 is not a armstrong number
# 41 is not a armstrong number
# 42 is not a armstrong number
# 43 is not a armstrong number
# 44 is not a armstrong number
# 45 is not a armstrong number
# 46 is not a armstrong number
# 47 is not a armstrong number
# 48 is not a armstrong number
# 49 is not a armstrong number
# 50 is not a armstrong number
# 51 is not a armstrong number
# 52 is not a armstrong number
# 53 is not a armstrong number
# 54 is not a armstrong number
# 55 is not a armstrong number
# 56 is not a armstrong number
# 57 is not a armstrong number
# 58 is not a armstrong number
# 59 is not a armstrong number
# 60 is not a armstrong number
# 61 is not a armstrong number
# 62 is not a armstrong number
# 63 is not a armstrong number
# 64 is not a armstrong number
# 65 is not a armstrong number
# 66 is not a armstrong number
# 67 is not a armstrong number
# 68 is not a armstrong number
# 69 is not a armstrong number
# 70 is not a armstrong number
# 71 is not a armstrong number
# 72 is not a armstrong number
# 73 is not a armstrong number
# 74 is not a armstrong number
# 75 is not a armstrong number
# 76 is not a armstrong number
# 77 is not a armstrong number
# 78 is not a armstrong number
# 79 is not a armstrong number
# 80 is not a armstrong number
# 81 is not a armstrong number
# 82 is not a armstrong number
# 83 is not a armstrong number
# 84 is not a armstrong number
# 85 is not a armstrong number
# 86 is not a armstrong number
# 87 is not a armstrong number
# 88 is not a armstrong number
# 89 is not a armstrong number
# 90 is not a armstrong number
# 91 is not a armstrong number
# 92 is not a armstrong number
# 93 is not a armstrong number
# 94 is not a armstrong number
# 95 is not a armstrong number
# 96 is not a armstrong number
# 97 is not a armstrong number
# 98 is not a armstrong number
# 99 is not a armstrong number
# 100 is not a armstrong number
# 101 is not a armstrong number
# 102 is not a armstrong number
# 103 is not a armstrong number
# 104 is not a armstrong number
# 105 is not a armstrong number
# 106 is not a armstrong number
# 107 is not a armstrong number
# 108 is not a armstrong number
# 109 is not a armstrong number
# 110 is not a armstrong number
# 111 is not a armstrong number
# 112 is not a armstrong number
# 113 is not a armstrong number
# 114 is not a armstrong number
# 115 is not a armstrong number
# 116 is not a armstrong number
# 117 is not a armstrong number
# 118 is not a armstrong number
# 119 is not a armstrong number
# 120 is not a armstrong number
# 121 is not a armstrong number
# 122 is not a armstrong number
# 123 is not a armstrong number
# 124 is not a armstrong number
# 125 is not a armstrong number
# 126 is not a armstrong number
# 127 is not a armstrong number
# 128 is not a armstrong number
# 129 is not a armstrong number
# 130 is not a armstrong number
# 131 is not a armstrong number
# 132 is not a armstrong number
# 133 is not a armstrong number
# 134 is not a armstrong number
# 135 is not a armstrong number
# 136 is not a armstrong number
# 137 is not a armstrong number
# 138 is not a armstrong number
# 139 is not a armstrong number
# 140 is not a armstrong number
# 141 is not a armstrong number
# 142 is not a armstrong number
# 143 is not a armstrong number
# 144 is not a armstrong number
# 145 is not a armstrong number
# 146 is not a armstrong number
# 147 is not a armstrong number
# 148 is not a armstrong number
# 149 is not a armstrong number
# 150 is not a armstrong number
# 151 is not a armstrong number
# 152 is not a armstrong number
# 153 is armstrong number
# 154 is not a armstrong number

# %%
#6.	Write a Python Program to Find the Sum of Natural Numbers?
def find_sum(number):
    if number<=0:
        print("Entre natural numbers only")
    else:
        number = ((number)*(number+1))/2
        return number
number = int(input("enter the number value"))
output = find_sum(number)
print(output)
